# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
url = "https://raw.githubusercontent.com/rajendra0968jangid/ML-Node-Project/main/student_data.csv"
df = pd.read_csv(url)
df
# Out:
#    Attendance  Test_Marks  Assignment_Marks  Practical_Marks  Final_Marks
# 0          85          75                80               78           82
# 1          90          88                85               86           89
# 2          78          65                70               72           68
# 3          92          90                88               91           93
# 4          88          85                84               83           86
# 5          76          60                65               67           63
# 6          95          95                92               94           96
# 7          80          70                75               74           73
# 8          70          55                60               58           59
# 9          89          82                86               84           85

# %%
X = df[['Attendance','Test_Marks','Assignment_Marks','Practical_Marks']]

Y = df[['Final_Marks']]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()

model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# save model
with open('model.pkl','wb') as file:
  pickle.dump(model, file)

print("Model trained and saved successfully")
# Out:
# Model trained and saved successfully

# %%
from google.colab import files
files.download("model.pkl")
